# %%
import pandas as pd
import numpy as np
import os

# %%
sale={}
for i in [2024,2023]:
    sale.update({i:pd.read_html('monthly_sales_by_category/'+str(i)+'.html')[2]})

# %%
sale[2024]
# Out:
#             Type                 Group                 Maker/Brand    Jan.  \
# 0           Cars              VW Group                          VW    1879
# 1           Cars              VW Group                        Audi     NaN
# 2           Cars              VW Group                       Skoda    1242
# 3           Cars              VW Group             Porsche (2013-)     NaN
# 4           Cars              VW Group              VW Group Total    3121
# ..           ...                   ...                         ...     ...
# 105        Buses  Small and Medium OEM                EKA Mobility       -
# 106        Buses  Small and Medium OEM                     Olectra      45
# 107        Buses  Small and Medium OEM  Small and Medium OEM Total      45
# 108        Buses           Buses Total                 Buses Total    6965
# 109  Grand Total           Grand Total                 Grand Total  487786
#
# ...

# %%
sale[2024].columns
# Out:
# Index(['Type', 'Group', 'Maker/Brand', 'Jan.', 'Feb.', 'Mar.', 'Apr.', 'May',
#        'Jun.', 'First Half (Jan.-Jun.)', 'Jul.', 'Aug.', 'Sep.', 'Oct.',
#        'Nov.', 'Dec.', 'Second Half (Jul.-Dec.)', 'Adjusted value', 'Total'],
#       dtype='object')

# %%
sale[2024].drop(columns=['Group','First Half (Jan.-Jun.)','Second Half (Jul.-Dec.)',
                         'Adjusted value','Total'],axis=1,inplace=True)

# %%
sale[2024]
# Out:
#             Type                 Maker/Brand    Jan.    Feb.    Mar.    Apr.  \
# 0           Cars                          VW    1879    1631    1847    1183
# 1           Cars                        Audi     NaN     NaN     NaN     NaN
# 2           Cars                       Skoda    1242    1028    1374    1266
# 3           Cars             Porsche (2013-)     NaN     NaN     NaN     NaN
# 4           Cars              VW Group Total    3121    2659    3221    2449
# ..           ...                         ...     ...     ...     ...     ...
# 105        Buses                EKA Mobility       -       -       -       1
# 106        Buses                     Olectra      45      43      42       0
# 107        Buses  Small and Medium OEM Total      45      43      42       1
# 108        Buses                 Buses Total    6965    6558    6525    5494
# 109  Grand Total                 Grand Total  487786  459797  456289  409143
#
# ...

# %%
sale[2024][sale[2024]['Type'].notna()]
# Out:
#             Type                 Maker/Brand    Jan.    Feb.    Mar.    Apr.  \
# 0           Cars                          VW    1879    1631    1847    1183
# 1           Cars                        Audi     NaN     NaN     NaN     NaN
# 2           Cars                       Skoda    1242    1028    1374    1266
# 3           Cars             Porsche (2013-)     NaN     NaN     NaN     NaN
# 4           Cars              VW Group Total    3121    2659    3221    2449
# ..           ...                         ...     ...     ...     ...     ...
# 105        Buses                EKA Mobility       -       -       -       1
# 106        Buses                     Olectra      45      43      42       0
# 107        Buses  Small and Medium OEM Total      45      43      42       1
# 108        Buses                 Buses Total    6965    6558    6525    5494
# 109  Grand Total                 Grand Total  487786  459797  456289  409143
#
# ...

# %%
for indx,value in zip(range(0,len(sale[2024])),sale[2024]['Type'].values):
    if value == 'Cars':
        sale[2024].iloc[indx,0] = 'PassengerCar'
        continue
    elif value == 'UVs/MPVs':
        sale[2024].iloc[indx,0] = 'SUV'
        continue
    elif value == 'Light Trucks':
        sale[2024].iloc[indx,0] = 'LightTruck'
        continue

# %%
sale[2024]
# Out:
#              Type                 Maker/Brand    Jan.    Feb.    Mar.    Apr.  \
# 0    PassengerCar                          VW    1879    1631    1847    1183
# 1    PassengerCar                        Audi     NaN     NaN     NaN     NaN
# 2    PassengerCar                       Skoda    1242    1028    1374    1266
# 3    PassengerCar             Porsche (2013-)     NaN     NaN     NaN     NaN
# 4    PassengerCar              VW Group Total    3121    2659    3221    2449
# ..            ...                         ...     ...     ...     ...     ...
# 105         Buses                EKA Mobility       -       -       -       1
# 106         Buses                     Olectra      45      43      42       0
# 107         Buses  Small and Medium OEM Total      45      43      42       1
# 108         Buses                 Buses Total    6965    6558    6525    5494
# 109   Grand Total                 Grand Total  487786  459797  456289  409143
#
# ...

# %%
sale[2024][sale[2024]['Type']=='Buses'].index[0]
# Out:
# 94

# %%
sale[2024].drop(index=list(range(sale[2024][sale[2024]['Type']=='Medium/Heavy Trucks'].index[0],len(sale[2024]))),
                axis=0,inplace=True)

# %%
sale[2024]
# Out:
#             Type                        Maker/Brand   Jan.   Feb.   Mar.  \
# 0   PassengerCar                                 VW   1879   1631   1847
# 1   PassengerCar                               Audi    NaN    NaN    NaN
# 2   PassengerCar                              Skoda   1242   1028   1374
# 3   PassengerCar                    Porsche (2013-)    NaN    NaN    NaN
# 4   PassengerCar                     VW Group Total   3121   2659   3221
# ..           ...                                ...    ...    ...    ...
# 74    LightTruck              Ashok Leyland (2022-)   6237   5871   5843
# 75    LightTruck  Ashok Leyland Group (2022-) Total   6237   5871   5843
# 76    LightTruck                       EKA Mobility      -      -      -
# 77    LightTruck         Small and Medium OEM Total      -      -      -
# 78    LightTruck                 Light Trucks Total  54995  52380  50904
#
#      Apr.    May   Jun.    Jul.    Aug. Sep. Oct. Nov. Dec.
# ...

# %%
sale[2024][sale[2024]['Maker/Brand'].isna()]
# Out:
# Empty DataFrame
# Columns: [Type, Maker/Brand, Jan., Feb., Mar., Apr., May, Jun., Jul., Aug., Sep., Oct., Nov., Dec.]
# Index: []

# %%
sale[2024].drop(index=sale[2024][sale[2024]['Maker/Brand'].isna()].index,axis=0,inplace=True)

# %%
sale[2024]
# Out:
#             Type                        Maker/Brand   Jan.   Feb.   Mar.  \
# 0   PassengerCar                                 VW   1879   1631   1847
# 1   PassengerCar                               Audi    NaN    NaN    NaN
# 2   PassengerCar                              Skoda   1242   1028   1374
# 3   PassengerCar                    Porsche (2013-)    NaN    NaN    NaN
# 4   PassengerCar                     VW Group Total   3121   2659   3221
# ..           ...                                ...    ...    ...    ...
# 74    LightTruck              Ashok Leyland (2022-)   6237   5871   5843
# 75    LightTruck  Ashok Leyland Group (2022-) Total   6237   5871   5843
# 76    LightTruck                       EKA Mobility      -      -      -
# 77    LightTruck         Small and Medium OEM Total      -      -      -
# 78    LightTruck                 Light Trucks Total  54995  52380  50904
#
#      Apr.    May   Jun.    Jul.    Aug. Sep. Oct. Nov. Dec.
# ...

# %%
sale[2024][['Maker/Brand']][sale[2024]['Maker/Brand'].str.contains('Total')].head()
# Out:
#                            Maker/Brand
# 4                       VW Group Total
# 6                   Toyota Group Total
# 8        Renault-Nissan Alliance Total
# 10  Hyundai Kia Automotive Group Total
# 12                    Ford Group Total

# %%
sale[2024].drop(index=sale[2024][['Maker/Brand']][sale[2024]['Maker/Brand'].str.contains('Total')].index,
                axis=0,inplace=True)

# %%
sale[2024].head(10)
# Out:
#             Type      Maker/Brand   Jan.   Feb.   Mar.   Apr.    May   Jun.  \
# 0   PassengerCar               VW   1879   1631   1847   1183   1610   1656
# 1   PassengerCar             Audi    NaN    NaN    NaN    NaN    NaN    NaN
# 2   PassengerCar            Skoda   1242   1028   1374   1266   1542   1231
# 3   PassengerCar  Porsche (2013-)    NaN    NaN    NaN    NaN    NaN    NaN
# 5   PassengerCar           Toyota   4052   4791   4551   4559   4639   4261
# 7   PassengerCar          Renault    856    828    928    977    743    603
# 9   PassengerCar          Hyundai  21632  16809  16784  16413  16311  15986
# 11  PassengerCar             Ford    NaN    NaN    NaN    NaN    NaN    NaN
# 13  PassengerCar            Honda   4095   3958   3794   2620   3269   2653
# 15  PassengerCar           Suzuki  92745  86890  82263  69339  78838  74016
#
#        Jul.     Aug. Sep. Oct. Nov. Dec.
# 0    1766.0   1876.0    -    -    -    -
# 1       NaN      NaN    -    -    -    -
# ...

# %%
sale[2024].iloc[:,2:-4] = sale[2024].iloc[:,2:-4].replace('-',np.nan)

# %%
sale[2024].dropna(axis=0,thresh=12,inplace=True)

# %%
sale[2024]
# Out:
#             Type            Maker/Brand   Jan.   Feb.   Mar.   Apr.    May  \
# 0   PassengerCar                     VW   1879   1631   1847   1183   1610
# 2   PassengerCar                  Skoda   1242   1028   1374   1266   1542
# 5   PassengerCar                 Toyota   4052   4791   4551   4559   4639
# 7   PassengerCar                Renault    856    828    928    977    743
# 9   PassengerCar                Hyundai  21632  16809  16784  16413  16311
# 13  PassengerCar                  Honda   4095   3958   3794   2620   3269
# 15  PassengerCar                 Suzuki  92745  86890  82263  69339  78838
# 21  PassengerCar                   Tata  14094  13268  13204  12249  12804
# 29           SUV                     VW   1388   1388   1682   1866   1663
# 30           SUV                  Skoda   1135   1226   1430   1313   1342
# 32           SUV                 Toyota  19138  18502  20521  14117  19289
# ...

# %%
for value in sale[2024][sale[2024]['Maker/Brand'].str.contains(r'\W\d{4}-\W')][['Maker/Brand']].iterrows():
    to_fill= value[1].values[0][:-8]
    sale[2024].loc[value[0],'Maker/Brand']=to_fill

# %%
sale[2024]
# Out:
#             Type          Maker/Brand   Jan.   Feb.   Mar.   Apr.    May  \
# 0   PassengerCar                   VW   1879   1631   1847   1183   1610
# 2   PassengerCar                Skoda   1242   1028   1374   1266   1542
# 5   PassengerCar               Toyota   4052   4791   4551   4559   4639
# 7   PassengerCar              Renault    856    828    928    977    743
# 9   PassengerCar              Hyundai  21632  16809  16784  16413  16311
# 13  PassengerCar                Honda   4095   3958   3794   2620   3269
# 15  PassengerCar               Suzuki  92745  86890  82263  69339  78838
# 21  PassengerCar                 Tata  14094  13268  13204  12249  12804
# 29           SUV                   VW   1388   1388   1682   1866   1663
# 30           SUV                Skoda   1135   1226   1430   1313   1342
# 32           SUV               Toyota  19138  18502  20521  14117  19289
# 34           SUV               Nissan   2863   2755   2701   2404   2211
# ...

# %%
sale[2024].dtypes
# Out:
# Type            object
# Maker/Brand     object
# Jan.            object
# Feb.            object
# Mar.            object
# Apr.            object
# May             object
# Jun.            object
# Jul.           float64
# Aug.           float64
# Sep.            object
# Oct.            object
# Nov.            object
# Dec.            object
# dtype: object

# %%
sale[2024][['Jan.', 'Feb.', 'Mar.', 'Apr.', 'May', 'Jun.', 'Jul.', 'Aug.']] = sale[2024][['Jan.', 'Feb.', 'Mar.', 'Apr.', 'May', 'Jun.', 'Jul.', 'Aug.']].astype('float')

# %%
sale[2024].dtypes
# Out:
# Type            object
# Maker/Brand     object
# Jan.           float64
# Feb.           float64
# Mar.           float64
# Apr.           float64
# May            float64
# Jun.           float64
# Jul.           float64
# Aug.           float64
# Sep.            object
# Oct.            object
# Nov.            object
# Dec.            object
# dtype: object

# %%
months = ['Jan.', 'Feb.', 'Mar.', 'Apr.', 'May', 'Jun.', 'Jul.', 'Aug.']
sale[2024][months] = sale[2024][months].apply(lambda row : row.fillna(np.ceil(row.mean())),axis=1)

# %%
sale[2024]
# Out:
#             Type          Maker/Brand     Jan.     Feb.     Mar.     Apr.  \
# 0   PassengerCar                   VW   1879.0   1631.0   1847.0   1183.0
# 2   PassengerCar                Skoda   1242.0   1028.0   1374.0   1266.0
# 5   PassengerCar               Toyota   4052.0   4791.0   4551.0   4559.0
# 7   PassengerCar              Renault    856.0    828.0    928.0    977.0
# 9   PassengerCar              Hyundai  21632.0  16809.0  16784.0  16413.0
# 13  PassengerCar                Honda   4095.0   3958.0   3794.0   2620.0
# 15  PassengerCar               Suzuki  92745.0  86890.0  82263.0  69339.0
# 21  PassengerCar                 Tata  14094.0  13268.0  13204.0  12249.0
# 29           SUV                   VW   1388.0   1388.0   1682.0   1866.0
# 30           SUV                Skoda   1135.0   1226.0   1430.0   1313.0
# 32           SUV               Toyota  19138.0  18502.0  20521.0  14117.0
# 34           SUV               Nissan   2863.0   2755.0   2701.0   2404.0
# ...

# %%
sale[2024]['Annual']=sale[2024][months].sum(axis=1)

# %%
sale[2024]['Monthly Avg']=np.round(sale[2024][months].mean(axis=1))

# %%
sale[2024].reset_index(drop=True,inplace=True)

# %%
sale[2024]
# Out:
#             Type          Maker/Brand     Jan.     Feb.     Mar.     Apr.  \
# 0   PassengerCar                   VW   1879.0   1631.0   1847.0   1183.0
# 1   PassengerCar                Skoda   1242.0   1028.0   1374.0   1266.0
# 2   PassengerCar               Toyota   4052.0   4791.0   4551.0   4559.0
# 3   PassengerCar              Renault    856.0    828.0    928.0    977.0
# 4   PassengerCar              Hyundai  21632.0  16809.0  16784.0  16413.0
# 5   PassengerCar                Honda   4095.0   3958.0   3794.0   2620.0
# 6   PassengerCar               Suzuki  92745.0  86890.0  82263.0  69339.0
# 7   PassengerCar                 Tata  14094.0  13268.0  13204.0  12249.0
# 8            SUV                   VW   1388.0   1388.0   1682.0   1866.0
# 9            SUV                Skoda   1135.0   1226.0   1430.0   1313.0
# 10           SUV               Toyota  19138.0  18502.0  20521.0  14117.0
# 11           SUV               Nissan   2863.0   2755.0   2701.0   2404.0
# ...

# %%
months = sale[2024].columns[2:-6]
months
# Out:
# Index(['Jan.', 'Feb.', 'Mar.', 'Apr.', 'May', 'Jun.', 'Jul.', 'Aug.'], dtype='object')

# %%
sale[2024].replace('-',0)
# Out:
#             Type          Maker/Brand     Jan.     Feb.     Mar.     Apr.  \
# 0   PassengerCar                   VW   1879.0   1631.0   1847.0   1183.0
# 1   PassengerCar                Skoda   1242.0   1028.0   1374.0   1266.0
# 2   PassengerCar               Toyota   4052.0   4791.0   4551.0   4559.0
# 3   PassengerCar              Renault    856.0    828.0    928.0    977.0
# 4   PassengerCar              Hyundai  21632.0  16809.0  16784.0  16413.0
# 5   PassengerCar                Honda   4095.0   3958.0   3794.0   2620.0
# 6   PassengerCar               Suzuki  92745.0  86890.0  82263.0  69339.0
# 7   PassengerCar                 Tata  14094.0  13268.0  13204.0  12249.0
# 8            SUV                   VW   1388.0   1388.0   1682.0   1866.0
# 9            SUV                Skoda   1135.0   1226.0   1430.0   1313.0
# 10           SUV               Toyota  19138.0  18502.0  20521.0  14117.0
# 11           SUV               Nissan   2863.0   2755.0   2701.0   2404.0
# ...

# %%
sale[2024].insert(2,'Year',2024)

# %%
sale[2024]
# Out:
#             Type          Maker/Brand  Year     Jan.     Feb.     Mar.  \
# 0   PassengerCar                   VW  2024   1879.0   1631.0   1847.0
# 1   PassengerCar                Skoda  2024   1242.0   1028.0   1374.0
# 2   PassengerCar               Toyota  2024   4052.0   4791.0   4551.0
# 3   PassengerCar              Renault  2024    856.0    828.0    928.0
# 4   PassengerCar              Hyundai  2024  21632.0  16809.0  16784.0
# 5   PassengerCar                Honda  2024   4095.0   3958.0   3794.0
# 6   PassengerCar               Suzuki  2024  92745.0  86890.0  82263.0
# 7   PassengerCar                 Tata  2024  14094.0  13268.0  13204.0
# 8            SUV                   VW  2024   1388.0   1388.0   1682.0
# 9            SUV                Skoda  2024   1135.0   1226.0   1430.0
# 10           SUV               Toyota  2024  19138.0  18502.0  20521.0
# 11           SUV               Nissan  2024   2863.0   2755.0   2701.0
# ...

# %%
pd.read_csv(os.getcwd()+'/cleaned/2023_monthly_category_sales.csv',index_col=0)
# Out:
#             Type          Maker/Brand  Year      Jan.      Feb.     Mar.  \
# 0   PassengerCar                   VW  2023    1379.0    1563.0   1791.0
# 1   PassengerCar                Skoda  2023    1609.0    1446.0   1764.0
# 2   PassengerCar               Toyota  2023    3386.0    4290.0   3463.0
# 3   PassengerCar              Renault  2023      59.0    1758.0   1283.0
# 4   PassengerCar              Hyundai  2023   22574.0   24493.0  23429.0
# 5   PassengerCar                Honda  2023    7638.0    6086.0   6689.0
# 6   PassengerCar               Suzuki  2023  100286.0  102565.0  83714.0
# 7   PassengerCar                 Tata  2023   15618.0   15295.0  15301.0
# 8            SUV                   VW  2023    1527.0    1748.0   2089.0
# 9            SUV                Skoda  2023    2209.0    1972.0   2668.0
# 10           SUV               Toyota  2023    9448.0   11033.0  14984.0
# 11           SUV               Nissan  2023    2803.0    2184.0   3260.0
# ...

# %%
sale={}

for year in [2024,2023]:
    
    sale.update({year:pd.read_html('monthly_sales_by_category/'+str(year)+'.html')[2]})
    
    sale[year].drop(columns=['Group','First Half (Jan.-Jun.)','Second Half (Jul.-Dec.)',
                         'Adjusted value','Total'],axis=1,inplace=True)
    
    sale[year].drop(index=list(range(sale[year][sale[year]['Type']=='Medium/Heavy Trucks'].index[0],len(sale[year]))),
                axis=0,inplace=True)
    
    for indx,value in zip(range(0,len(sale[year])),sale[year]['Type'].values):
        if value == 'Cars':
            sale[year].iloc[indx,0] = 'PassengerCar'
            continue
        elif value == 'UVs/MPVs':
            sale[year].iloc[indx,0] = 'SUV'
            continue
        elif value == 'Light Trucks':
            sale[year].iloc[indx,0] = 'LightTruck'
            continue
    
    sale[year].drop(index=sale[year][sale[year]['Maker/Brand'].isna()].index,axis=0,inplace=True)
    
    sale[year].drop(index=sale[year][['Maker/Brand']][sale[year]['Maker/Brand'].str.contains('Total')].index,
                axis=0,inplace=True)
    
    sale[year].iloc[:,2:-4] = sale[year].iloc[:,2:-4].replace('-',np.nan)
    
    sale[year].dropna(axis=0,thresh=8,inplace=True)
    
    for value in sale[year][sale[year]['Maker/Brand'].str.contains(r'\W\d{4}-\W')][['Maker/Brand']].iterrows():
        to_fill= value[1].values[0][:-8]
        sale[year].loc[value[0],'Maker/Brand']=to_fill
        
    if year==2024:
        months = sale[year].columns[2:-4]
        sale[year].replace('-',0,inplace=True)
    else:
        months = sale[year].columns[2:]
        
    
    sale[year][months] = sale[year][months].astype('float')
    
    sale[year][months] = sale[year][months].apply(lambda row : row.fillna(np.ceil(row.mean())),axis=1)
    
    sale[year].insert(2,'Year',year)
    
    sale[year]['Annual']=sale[year][months].sum(axis=1)
    
    sale[year]['Monthly Avg']=np.round(sale[year][months].mean(axis=1))
    
    sale[year].reset_index(drop=True,inplace=True)
    
    file_name = os.getcwd()+'/testing_cleaned/'+str(year)+'_monthly_category_sales.csv'
    
    sale[year].to_csv(file_name)
    
    if year==2024:
        master_data = sale[year]
    else:
        master_data = pd.concat([master_data,sale[year]],axis=0,ignore_index=True)
    
master_data
master_data.to_csv(os.getcwd()+'/testing_cleaned/'+'monthly_sales_master_data.csv')

# %%
master_data
# Out:
#             Type          Maker/Brand  Year     Jan.     Feb.     Mar.  \
# 0   PassengerCar                   VW  2024   1879.0   1631.0   1847.0
# 1   PassengerCar                Skoda  2024   1242.0   1028.0   1374.0
# 2   PassengerCar               Toyota  2024   4052.0   4791.0   4551.0
# 3   PassengerCar              Renault  2024    856.0    828.0    928.0
# 4   PassengerCar              Hyundai  2024  21632.0  16809.0  16784.0
# ..           ...                  ...   ...      ...      ...      ...
# 61    LightTruck  Mahindra & Mahindra  2023  20998.0  20146.0  21537.0
# 62    LightTruck                Isuzu  2023    813.0    796.0    798.0
# 63    LightTruck        Eicher Motors  2023   1255.0   1229.0   1230.0
# 64    LightTruck         Force Motors  2023   1889.0   1850.0   1850.0
# 65    LightTruck        Ashok Leyland  2023   6367.0   6235.0   6238.0
#
#        Apr.      May     Jun.     Jul.     Aug.     Sep.     Oct.     Nov.  \
# ...

# %%
master_data.dtypes
# Out:
# Type            object
# Maker/Brand     object
# Year             int64
# Jan.           float64
# Feb.           float64
# Mar.           float64
# Apr.           float64
# May            float64
# Jun.           float64
# Jul.           float64
# Aug.           float64
# Sep.           float64
# Oct.           float64
# Nov.           float64
# Dec.           float64
# Annual         float64
# Monthly Avg    float64
# dtype: object

# %% [markdown]
# ___
